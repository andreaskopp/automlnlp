# %% [markdown]
# # Sentiment Classification Multilabel with AutoML for NLP

# %%
import pandas as pd
import numpy as np
import json
import requests
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from azure.identity import DefaultAzureCredential
from azure.ai.ml import MLClient

from azure.ai.ml.constants import AssetTypes
from azure.ai.ml import Input

from azure.ai.ml import automl
import re

pd.set_option('display.max_colwidth', None)
# pd.set_option('display.max_rows', None)

# %% [markdown]
# # 1. Retrieve and preprocess data

# %% [markdown]
# ## Option A: for Sodexo Input

# %%
'''
sentiment_df = pd.read_excel('../../input_data/validation_set_topic_classification_advanced_task.xls')

topic_cols = ['main_topic_1', 'main_topic_2', 'main_topic_3','secondary_topic_1', 'secondary_topic_2', 'secondary_topic_3']

sentiment_df[topic_cols] = sentiment_df[topic_cols].fillna('Missing')

# get unique list of labels accross relevant columns
labels = pd.unique(sentiment_df[topic_cols].values.ravel('K'))

# build dict with label names as required by AutoML for NLP multilabel
replace_values = dict((label, '') for label in labels)

for key, value in replace_values.items():
    new_value = key.lower().replace(' ', '_').replace('/', '').replace('__','_')
    replace_values[key] = new_value

# replace_values
'''

# %%
'''
def generate_multilabel_col(col, no_value='Missing'):
    
    multilabel = [replace_values[label] for label in [col[0], col[1], col[2], col[3], col[4], col[5]] if label != no_value]

    return chr(34) + str(multilabel) + chr(34)

sentiment_df['multilabel'] = sentiment_df[topic_cols].apply(generate_multilabel_col, axis = 1)

# sentiment_df
'''

# %% [markdown]
# ## Option B: for AML Labeling Export (MS annotated dataset)

# %%
sent_rel_df = pd.read_csv('../../input_data/andreas-labelled-raw.csv')

# %%
sent_rel_df.sample(5)
# Out:
#          index  \
# 3255  17257220
# 4382  17249909
# 1509  17257627
# 3980  17248788
# 2378  17252960
#
#                                                                                                                                   comments  \
# 3255  Onion rings were soggy and dripping with grease. The burger was good but the onion rings will get you shut down by the health board.
# 4382                                                                 Both tacos fell apart because they were stuck to bottom of container.
# 1509                                                                                                                                  Poor
# 3980                                                                                     A little sad that I only got 2 ribs instead of 5.
# 2378                                                                                                                          Good. Thanks
#
#                                                   Label LabelConfidence
# 3255  Bad quality or taste,Good food quality,Good taste           1,1,1
# 4382       Bad quality or taste,Inappropriate packaging             1,1
# 1509                          Global negative feedbacks               1
# 3980           Wrong or missing order,Portion too small             1,1
# 2378                          Global positive feedbacks               1

# %%
# get unique list of labels and drop entries with multiple labels in one line (separated by comma)
labels = list(pd.unique(sent_rel_df['Label']))
labels = list(set([element for element in labels if ',' not in element]))

# combine 'good food quality' and 'good taste' to a single label 'good quality or taste'
gf = 'Good food quality'
gt = 'Good taste'
gqt = 'Good quality or taste'

labels.remove(gf)
labels = [gqt if item == gt else item for item in labels]

# build dict with label names according to the naming conventions of AutoML for NLP
replace_values = dict((label, '') for label in labels)

for key, value in replace_values.items():
    new_value = key.lower().replace(' ', '_')
    replace_values[key] = new_value

replace_values
# Out:
# {'Bad service': 'bad_service',
#  'Misleading images': 'misleading_images',
#  'Waited too long': 'waited_too_long',
#  'Global negative feedbacks': 'global_negative_feedbacks',
#  'Good services': 'good_services',
#  'Product not available': 'product_not_available',
#  'App works well': 'app_works_well',
#  'Wrong or missing order': 'wrong_or_missing_order',
#  'App to improve': 'app_to_improve',
#  'Good food temperature': 'good_food_temperature',
#  'Inappropriate packaging': 'inappropriate_packaging',
#  'Portion too small': 'portion_too_small',
#  'Not enough options': 'not_enough_options',
#  'Bad quality or taste': 'bad_quality_or_taste',
#  'Global positive feedbacks': 'global_positive_feedbacks',
#  'Good quality or taste': 'good_quality_or_taste',
#  'Too expensive': 'too_expensive',
#  'Other': 'other',
#  'Arrived on time': 'arrived_on_time',
#  'Bad food temperature': 'bad_food_temperature',
#  'Packaging not sustainable': 'packaging_not_sustainable'}

# %%
def adjust_labels(input):
    input_list = input.split(',')

    # combine 'good food quality' and 'good taste' to a single label 'good quality or taste'
    if gf in input_list or gt in input_list:
        input_list.append(gqt)
        if gf in input_list:
            input_list.remove(gf)
        if gt in input_list:
            input_list.remove(gt)

    # rename labels according to AutoML for NLP convention
    shortnames = [replace_values[item] for item in input_list]
    
    # add double quotes (chr 34) to the whole list and convert to string
    result = chr(34) + str(shortnames) + chr(34)
    
    return result

sent_rel_df['multilabel'] = sent_rel_df['Label'].apply(adjust_labels)

# %%
# remove special characters from comments
def remove_special_chars(text):
    regex = '[^0-9a-zA-Z$£!.,:;/& ]+'
    result = re.sub(regex, '', text)
    return result

# remove_special_chars('a£b c$def!')

sent_rel_df['comments'] = sent_rel_df['comments'].apply(remove_special_chars)

# %%
# Generate train and validation splits
cols_of_interest = ['comments', 'multilabel']

# train_df, val_df = train_test_split(sentiment_df[cols_of_interest], test_size=0.2, stratify=sentiment_df['sentiment'], random_state=123)
train_df, val_df = train_test_split(sent_rel_df[cols_of_interest], test_size=0.2, random_state=123)

# %%
# review of preprocessed data
train_df.sample(20)
# Out:
#                                                                                                                                                                                                                                                              comments  \
# 2792                                                                                                                                                                                                                                          Could have been warmer.
# 2872                                                                                                                                                                                                                                 On time and everything was there
# 1961  I ordered a bacon sandwich w/ a side sausage patty. Only received the patty. When I mentioned this I was told "that's how it came through" I showed my receipt and received the same response until the manager got involved and told them to make the sandwich
# 1007                                                                                                                                                                                                                                                     Great stuff!
# 4424                                                                                                                                                                                                Felt like it didn’t have a lot of flavor. More masa than anything
# 1423                                                                                                                                                                                             It took a lot of time to load the app, however it eventually worked.
# 1933                                                                                                                                                                                                                                        Apps are too complicated…
# 2222                                                                                                                                                                                                                                                 Forgot my bacon.
# 3164                                                                                                                                                                                                                                  Always great service with Fiona
# 3390                                                                                                                                                                                                                                         My food isn't in the box
# 2973                                                                                                                                                                                                                                 Once again nice to have you back
# 1221                                                                                                                                                                                                                                  Pretty great for heat yourself.
# 4087                                                                                                                                                                                                            Chicken was over-sized and the meal lack spice/flavor
# 2667                                                                                                                                                                                                                                      All-round great experience.
# 98                                                   Breakfast Sandwich was ice cold. First time ordering food from this cafe and was not impressed with overall quality. Staff is amazing, food quality not so much. Hoping it’s just a one off and will get better.
# 2526                                                                                                                                                              I attempted to get hot sauce and ketchup… my food was swimming in condiments. Gotta be a better way
# 1270                                                                                                                                                                                                                                                  Calum was great
# 2600                                                                                                                                                                                                                                             I love Blueberries !
# 2946                                                                                                                                                                                                                          Plantin and pineapple salsa were great!
# 4007                                                                                                                                                                                                       Grateful for the new cafe and smooth touch less service!!!
#
#                                                                multilabel
# 2792                                           "['bad_food_temperature']"
# 2872                                                "['arrived_on_time']"
# 1961                          "['wrong_or_missing_order', 'bad_service']"
# 1007                                      "['global_positive_feedbacks']"
# 4424                                           "['bad_quality_or_taste']"
# 1423                                                 "['app_to_improve']"
# 1933                                                 "['app_to_improve']"
# 2222                                         "['wrong_or_missing_order']"
# 3164                                                  "['good_services']"
# 3390                                         "['wrong_or_missing_order']"
# 2973                                      "['global_positive_feedbacks']"
# 1221                                      "['global_positive_feedbacks']"
# 4087                                           "['bad_quality_or_taste']"
# 2667                                      "['global_positive_feedbacks']"
# 98    "['bad_food_temperature', 'bad_quality_or_taste', 'good_services']"
# 2526                                           "['bad_quality_or_taste']"
# 1270                                                  "['good_services']"
# 2600                                          "['good_quality_or_taste']"
# 2946                                          "['good_quality_or_taste']"
# 4007                                      "['global_positive_feedbacks']"

# %%
# train_df.to_csv('../../input_data/ms_sentiment_multilabel_train.csv', index = False)
# val_df.to_csv('../../input_data/ms_sentiment_multilabel_val.csv', index = False)

# %%
train_df.to_csv('./sentiment_multilabel_train_mltable/sentiment_multilabel_train.csv', index = False)

val_df.to_csv('./sentiment_multilabel_val_mltable/sentiment_multilabel_val.csv', index = False)

# %% [markdown]
# # 2. Configure AutoML for NLP Job

# %%
credential = DefaultAzureCredential(exclude_interactive_browser_credential=False)
ml_client = None
try:
    ml_client = MLClient.from_config(credential)
except Exception as ex:
    print(ex)
    # Enter details of your AML workspace
    subscription_id = '2dbd7833-129e-4a48-b976-e6dd28a92c29'
    resource_group = 'sodexo-nlp'
    workspace = 'sodexo-nlp'
    ml_client = MLClient(credential, subscription_id, resource_group, workspace)
# Out:
# We could not find config.json in: . or in its parent directories.

# %%
workspace = ml_client.workspaces.get(name=ml_client.workspace_name)

output = {}
output["Workspace"] = ml_client.workspace_name
output["Subscription ID"] = ml_client.connections._subscription_id
output["Resource Group"] = workspace.resource_group
output["Location"] = workspace.location
output
# Out:
# {'Workspace': 'sodexo-nlp',
#  'Subscription ID': '2dbd7833-129e-4a48-b976-e6dd28a92c29',
#  'Resource Group': 'sodexo-nlp',
#  'Location': 'westeurope'}

# %%
# general job parameters
compute_name = "gpu-cluster"
exp_name = "automl-nlp-sentiment-multilabel-classification"

training_data_path = './sentiment_multilabel_train_augmented_mltable/' # AUGMENTED !!!
validation_data_path = './sentiment_multilabel_val_mltable/'

# Training MLTable defined locally, with local data to be uploaded
my_training_data_input = Input(type=AssetTypes.MLTABLE, path=training_data_path)

# Validation MLTable defined locally, with local data to be uploaded
my_validation_data_input = Input(type=AssetTypes.MLTABLE, path=validation_data_path)

# Create the AutoML job with the related factory-function.
text_classification_job = automl.text_classification_multilabel(
    compute=compute_name,
    # name="sdk multilabel",
    experiment_name=exp_name,
    training_data=my_training_data_input,
    validation_data=my_validation_data_input,
    target_column_name="multilabel",
    primary_metric="accuracy",
    tags={"task": "sentiment-multilabel-classification-sdkv2"},
)

text_classification_job.set_limits(timeout_minutes=120)
text_classification_job.set_featurization(dataset_language='eng')
# Out:
# Class TextClassificationMultilabelJob: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %%
returned_job = ml_client.jobs.create_or_update(
    text_classification_job
)  # submit the job to the backend

print(f"Created job: {returned_job}")
ml_client.jobs.stream(returned_job.name)
# Out:
# Uploading sentiment_multilabel_train_augmented_mltable (0.34 MBs): 100%|██████████| 341085/341085 [00:00<00:00, 15110153.04it/s]
#
#
# Readonly attribute primary_metric will be ignored in class <class 'azure.ai.ml._restclient.v2022_02_01_preview.models._models_py3.TextClassificationMultilabel'>
# Created job: TextClassificationMultilabelJob({'task_type': <TaskType.TEXT_CLASSIFICATION_MULTILABEL: 'TextClassificationMultilabel'>, 'environment_id': None, 'environment_variables': None, 'outputs': {}, 'type': 'automl', 'status': 'NotStarted', 'log_files': None, 'name': 'great_goat_fq9lxr6rjz', 'description': None, 'tags': {'task': 'sentiment-multilabel-classification-sdkv2'}, 'properties': {'mlflow.source.git.repoURL': 'https://github.com/andreaskopp/sodexo-nlp', 'mlflow.source.git.branch': 'main', 'mlflow.source.git.commit': '603d681674fa1c9809bbe16bf1ecb5659af74dcb', 'azureml.git.dirty': 'True'}, 'id': '/subscriptions/2dbd7833-129e-4a48-b976-e6dd28a92c29/resourceGroups/sodexo-nlp/providers/Microsoft.MachineLearningServices/workspaces/sodexo-nlp/jobs/great_goat_fq9lxr6rjz', 'base_path': './', 'creation_context': <azure.ai.ml._restclient.v2022_02_01_preview.models._models_py3.SystemData object at 0x7f3eb9bc5310>, 'serialize': <msrest.serialization.Serializer object at 0x7f3eb9bc5a30>, 'inputs': {}, 'display_name': 'great_goat_fq9lxr6rjz', 'experiment_name': 'automl-nlp-sentiment-multilabel-classification', 'compute': 'gpu-cluster', 'services': {'Tracking': <azure.ai.ml._restclient.v2022_02_01_preview.models._models_py3.JobService object at 0x7f3eb9bc5940>, 'Studio': <azure.ai.ml._restclient.v2022_02_01_preview.models._models_py3.JobService object at 0x7f3eb9bc5280>}, 'resources': <azure.ai.ml._restclient.v2022_02_01_preview.models._models_py3.ResourceConfiguration object at 0x7f3eb9bc5a00>, 'identity': None, 'log_verbosity': <LogVerbosity.INFO: 'Info'>, 'primary_metric': <ClassificationMultilabelPrimaryMetrics.ACCURACY: 'Accuracy'>, 'target_column_name': 'multilabel', 'training_data': {'type': 'mltable', 'path': 'azureml://datastores/workspaceblobstore/paths/LocalUpload/2bbe84bcdd348c753b194722091f3c14/sentiment_multilabel_train_augmented_mltable', 'mode': 'ro_mount'}, 'validation_data': {'type': 'mltable', 'path': 'azureml://datastores/workspaceblobstore/paths/LocalUpload/42ea5697e907012320a39e452aa4d409/sentiment_multilabel_val_mltable', 'mode': 'ro_mount'}, 'data': <azure.ai.ml._restclient.v2022_02_01_preview.models._models_py3.NlpVerticalDataSettings object at 0x7f3eb9bc5700>, 'limits': <azure.ai.ml.entities._job.automl.nlp.nlp_limit_settings.NlpLimitSettings object at 0x7f3eb9bc5610>, 'featurization': <azure.ai.ml.entities._job.automl.nlp.nlp_featurization_settings.NlpFeaturizationSettings object at 0x7f3eb9bc57f0>})
# RunId: great_goat_fq9lxr6rjz
# Web View: https://ml.azure.com/runs/great_goat_fq9lxr6rjz?wsid=/subscriptions/2dbd7833-129e-4a48-b976-e6dd28a92c29/resourcegroups/sodexo-nlp/workspaces/sodexo-nlp
#
# Execution Summary
# =================
# RunId: great_goat_fq9lxr6rjz
# Web View: https://ml.azure.com/runs/great_goat_fq9lxr6rjz?wsid=/subscriptions/2dbd7833-129e-4a48-b976-e6dd28a92c29/resourcegroups/sodexo-nlp/workspaces/sodexo-nlp

# %% [markdown]
# # 3. Test Webservice

# %%
val_df = pd.read_csv('./sentiment_multilabel_val_mltable/sentiment_multilabel_val.csv')
train_df = pd.read_csv('./sentiment_multilabel_train_mltable/sentiment_multilabel_train.csv')

# %%
train_df.sample(10)
# Out:
#                                                                                                                                  comments  \
# 523                                                                                                                        Food was cold.
# 1853                                                                   First time using this service and it was quick and easy. Great app
# 2150                                                 On top of being cold, One rid was eatable one was burned and the third was 90 fat!!!
# 33                                                                                                                      chicken was burnt
# 3290                                                                          Can we cook shrimps with the rice just like the real paella
# 2494  I was sceptical on how this food would be, but I have to say if was delicious. Still lovely and warm , crispy batter. Well done all
# 1473                                                                  Please do this every Friday. So good! An portion was the right size
# 2088                                                                                        Chicken noodles soup did not have any flavor.
# 3580                                                                                                         Bring the sandwich bar back!
# 1953                                                                                                                                Brill
#
#                                                 multilabel
# 523                             "['bad_food_temperature']"
# 1853               "['app_works_well', 'arrived_on_time']"
# 2150    "['bad_food_temperature', 'bad_quality_or_taste']"
# 33                              "['bad_quality_or_taste']"
# 3290                            "['bad_quality_or_taste']"
# 2494  "['good_food_temperature', 'good_quality_or_taste']"
# 1473                       "['global_positive_feedbacks']"
# 2088                            "['bad_quality_or_taste']"
# 3580                              "['not_enough_options']"
# 1953                       "['global_positive_feedbacks']"

# %%
data = val_df[['comments']].to_dict(orient='records')

scoring_uri = 'http://20.238.236.162:80/api/v1/service/sentiment-multilabel-nochar/score'
key = 'YbdlEAoJmatJHdnOyOq778hadKMYDFf1'

# %%
# Set the appropriate headers
headers = {"Content-Type": "application/json"}
headers["Authorization"] = f"Bearer {key}"

# Make the request and display the response and logs
data_dict = {"Inputs": {"data": data},
            "GlobalParameters": {"method": "predict"}}

data = json.dumps(data_dict)
resp = requests.post(scoring_uri, data=data, headers=headers)

# %%
resp
# Out:
# <Response [200]>

# %%
# resp.text

# %%
y_true_series = val_df['multilabel']
y_pred_list = json.loads(resp.text)['Results']

# get labels from original dataset
labels = [value for value in replace_values.values()] 

y_pred_arr = np.zeros([len(y_pred_list), len(labels)])
y_true_arr = np.zeros([len(y_true_series), len(labels)])

# build encoded matrix for y_pred_arr
for row_idx, observation in enumerate(y_pred_list):
    for label_idx, label in enumerate(labels):
        if label in observation:
            y_pred_arr[row_idx, label_idx] = 1

# build encoded matrix for y_true_arr
for row_idx, observation in enumerate(y_true_series):
    for label_idx, label in enumerate(labels):
        if observation.find(label) != -1:
            y_true_arr[row_idx, label_idx] = 1

# %%
val_df
# Out:
#                                                                                                                              comments  \
# 0                                                                                                 Great staff and the sandwich tasted
# 1                                                                                                          Great service from Adrian
# 2                                           Excellent experience. Thanks for the wonderful Meals every time I ordered. I really them.
# 3                                     Food was just done as I got there and the cook was very friendly. The burger also tasted great!
# 4                                                                                                          Great service from Callum!
# ..                                                                                                                                ...
# 893                                                                                        Plz clean ketchup packets, they are sticky
# 894                                      Great first experience. Took a bit long to set up the app but next time it will be easier. :
# 895  Please include the default toppings so in future orders I can ask them to hold these toppings i.e. lettuce, tomato, onions, etc.
# 896                                                                         Food was amazing. You guys are awesome. Have a great day.
# 897                                                                                                               Never got the drink
#
#                                                           multilabel
# 0                       "['good_services', 'good_quality_or_taste']"
# 1                                                "['good_services']"
# 2           "['global_positive_feedbacks', 'good_quality_or_taste']"
# 3    "['good_services', 'arrived_on_time', 'good_quality_or_taste']"
# 4                                                "['good_services']"
# ..                                                               ...
# 893                                                "['bad_service']"
# 894                                  "['global_positive_feedbacks']"
# 895                                             "['app_to_improve']"
# 896                     "['good_services', 'good_quality_or_taste']"
# 897                                     "['wrong_or_missing_order']"
#
# [898 rows x 2 columns]

# %%
print(classification_report(y_true_arr, y_pred_arr, target_names=labels, zero_division=True))
# Out:
#                            precision    recall  f1-score   support
#
#             good_services       0.98      0.70      0.81       174
#         misleading_images       1.00      0.00      0.00         5
#                     other       1.00      0.00      0.00        21
#    wrong_or_missing_order       1.00      0.29      0.45       126
#     good_food_temperature       1.00      0.00      0.00         8
#     product_not_available       1.00      0.00      0.00        12
# global_negative_feedbacks       1.00      0.00      0.00        37
#     good_quality_or_taste       0.97      0.81      0.88       229
#      bad_quality_or_taste       0.84      0.72      0.78       136
#        not_enough_options       1.00      0.00      0.00        43
#               bad_service       1.00      0.00      0.00        17
#   inappropriate_packaging       1.00      0.00      0.00        23
#             too_expensive       1.00      0.00      0.00         8
#            app_works_well       1.00      0.00      0.00         9
# packaging_not_sustainable       1.00      0.00      0.00         4
#           arrived_on_time       1.00      0.00      0.00        33
# global_positive_feedbacks       0.94      0.68      0.79       107
#           waited_too_long       1.00      0.00      0.00        31
#      bad_food_temperature       1.00      0.00      0.00        32
#            app_to_improve       1.00      0.00      0.00        56
#         portion_too_small       1.00      0.00      0.00        43
#
#                 micro avg       0.94      0.45      0.61      1154
#                 macro avg       0.99      0.15      0.18      1154
#              weighted avg       0.97      0.45      0.51      1154
#               samples avg       0.96      0.48      0.50      1154

# %%
val_df['predicted'] = y_pred_list

# %%
val_df.sample(50)
# Out:
#                                                                                                                                                                                                                                                            comments  \
# 839                                                                                                                                                                                                                           Cafeteria food is definitely improved
# 744                                                                            Came in plastic and wasnt sure if I could microwave it. Did I need to bring my own plate App said order would take 2hrs. Wanted to cancel but had paid and wasnt sure if it could be
# 729                                                                                                                                                                                                         Eggs were fluffy and bacon crispy. Great job! Thank you
# 842                                                                                                                                                                                                           No sour cream or salsa came with burrito per request.
# 141                                                                                            First app order when collecting order was told no app orders are received on nights fortunately someone else had changed their mind and a spare order was available.
# 690                                                                                            Missing soup. Salad is bland, would be nice to have good mix of vegetables instead. Main meal meat is good, but rice is bland. Overall, portion sizes are too small.
# 193  I enjoy the food but I am always disappointed that the pictures you use for each item do not match what it really looks like. It is misleading  the pictures contain more ingredients than you use and I feel unhappy that I did not get what the picture was.
# 831                                                                                                                                                                                                                      No sausages on bap, no knife to spread jam
# 325                                                                                                                                           Fries were not cooked enough. Third time in a row. Felt like I was eating raw potatoes. The fries used to be so good.
# 347                                                                                                                                                                                                                                           great service! easy!!
# 380    I paid 9 dollars for a quesadilla and there was hardly any chicken on it. Maybe 2oz worth if that aftergoing back more chicken was made and just put on my plate and not in the quesadilla. A new quesadilla should of been made with more chicken and chees
# 296                                                                                                                                                                                                                           Amazing service from staff, as usual.
# 590                                                                                                                                              Coffee today is undrinkable. Who ever brewed it clearly hasnt been shown how to brew coffee. Looks like weak tea.
# 516                                                                                                                                                                                                                                                  Cold and soggy
# 662                                                                                                                                                                                                                                                      Convenient
# 748                                                                                                                                                                                                                                                 Always friendly
# 826                                                                                                                                                                            Good ingredients but too much dressing. Kind of soggy when I did my on time pick up.
# 609                                                                                                                                                                                                                                    Food was also hot, thank you
# 549                                                                                                                                                                                        Order included and was charged for bacon, which was not on the sandwich.
# 178                                                                                                                                                                          Fries need to be in better packaging to avoid air being trapped and making them soggy.
# 132                                                                                                                                           For the second time they made my tuna melt on stale wheat bread not on toasted panini as advertised. Mushy and soggy.
# 462                                                                                                                                                                                                  Please remove these everyorder surveys. They lock up my phone.
# 319                                                                                                                 I know that the barista is new but the coffee tastes really burned and I know he felt rushed cause a bunch of orders were coming in all at once
# 11                                                                                                                                                                                                                                                       Pizza day!
# 119                                                                                                                                                                                                                                                Awesome service!
# 201                                                                                                                                                       Hash browns were like chewing on cardboard. Lots of water from the omelet had everything in a small pool.
# 19                                                                                                                                                                                            Kinda dry hard to eat .... customer service was ok....app was lagging
# 297                                                                                                                                                                                         Instead of a twix and sandwich, I received a can of lilt and a sandwich
# 641                                                                                                                                                                                                            Lots of onions, little chicken. Overall not too bad.
# 833                                                                                                                                                                                                                                             Lindsay is awesome!
# 664                                                                                                                                                          I have one minor comment:the chicken or the batter could have been a bit more seasoned. But still good
# 860                                                                                                                                                                                                                                              Great job Gang!!!!
# 536                                                                                                                                                                                          My order was perfectly on time and Cleusa and team are always friendly
# 191                                                                                                                                                                                                                                 Fruit was moldy in refrigerator
# 501                                                                                                                                                                                                                                                Fantastic thanks
# 457                                                                                                                                       Cardboard boxes get soggy from steam and heat, perhaps wrapping in a layer of parchment or wax paper will help absorb it.
# 482                                                                                                                                                                                                                                                     Fab! Thanks
# 680                                                                                                                                                                                                        My order wasnt received or ready when I went to pick up.
# 836                                                                                                I understand things happen, but having a new estimated time would be helpfulthat way the customer can decide whether to cancel the order and get something else.
# 292                                                                                                                                                                                                                                Felt the portion was a tad small
# 215                                                                                                                                                                                                                                Friendly staff. Delicious drink.
# 32                                                                                                                                                                                                      I love the girl in the store she is super friendly and good
# 740                             I miss my Farmers eggs with peppers and bacon and hash browns or even my hash browns with peppers and bacon Im so sad that every Tuesday has to be taco day number thats one of my days I come to the office I have no other choice
# 771                                                                                                                                                                                                                                                  Great as usual
# 534                                                                                                                                                                                                                                Excellent service, cant fault it
# 182                                                                                                                                                                                                              Not really minestrone since too little vegetables.
# 133                                                                                                                                              Order was wrong. Had items in it I did not order. Had kidney beans instead of green beans, and no cheese or pepper
# 47                                                                                                                                                                                                                                        Delicious!!! Thank you!!!
# 498                                                                                                                                                                                                                                          Great food and service
# 473                                                                                                                                 Could it be optional to receive plastic cutlery We already have cutlery available and this created additional waste. Thank you!
#
#                                                                 multilabel  \
# 839                                            "['good_quality_or_taste']"
# 744                                "['app_to_improve', 'waited_too_long']"
# 729                                            "['good_quality_or_taste']"
# 842                                           "['wrong_or_missing_order']"
# 141                         "['wrong_or_missing_order', 'app_to_improve']"
# 690  "['bad_quality_or_taste', 'not_enough_options', 'portion_too_small']"
# 193                       "['misleading_images', 'good_quality_or_taste']"
# 831              "['wrong_or_missing_order', 'global_negative_feedbacks']"
# 325                                             "['bad_quality_or_taste']"
# 347                                                    "['good_services']"
# 380                                                "['portion_too_small']"
# 296                                                    "['good_services']"
# 590                                             "['bad_quality_or_taste']"
# 516                     "['bad_quality_or_taste', 'bad_food_temperature']"
# 662                                        "['global_positive_feedbacks']"
# 748                                                    "['good_services']"
# 826                    "['bad_quality_or_taste', 'good_quality_or_taste']"
# 609                                            "['good_food_temperature']"
# 549                                           "['wrong_or_missing_order']"
# 178                                          "['inappropriate_packaging']"
# 132                        "['bad_quality_or_taste', 'misleading_images']"
# 462                                                   "['app_to_improve']"
# 319                                             "['bad_quality_or_taste']"
# 11                                         "['global_positive_feedbacks']"
# 119                                                    "['good_services']"
# 201                                             "['bad_quality_or_taste']"
# 19           "['bad_quality_or_taste', 'good_services', 'app_to_improve']"
# 297                                           "['wrong_or_missing_order']"
# 641                       "['portion_too_small', 'good_quality_or_taste']"
# 833                                                    "['good_services']"
# 664               "['global_negative_feedbacks', 'good_quality_or_taste']"
# 860                                                    "['good_services']"
# 536                                 "['arrived_on_time', 'good_services']"
# 191                                             "['bad_quality_or_taste']"
# 501                                        "['global_positive_feedbacks']"
# 457                                          "['inappropriate_packaging']"
# 482                                        "['global_positive_feedbacks']"
# 680                        "['waited_too_long', 'wrong_or_missing_order']"
# 836                                                   "['app_to_improve']"
# 292                                                "['portion_too_small']"
# 215                           "['good_services', 'good_quality_or_taste']"
# 32                                                     "['good_services']"
# 740                                               "['not_enough_options']"
# 771                                        "['global_positive_feedbacks']"
# 534                                                    "['good_services']"
# 182                                                "['portion_too_small']"
# 133                                           "['wrong_or_missing_order']"
# 47                                             "['good_quality_or_taste']"
# 498                           "['good_services', 'good_quality_or_taste']"
# 473                                        "['packaging_not_sustainable']"
#
#                                   predicted
# 839                  [bad_quality_or_taste]
# 744                                      []
# 729                 [good_quality_or_taste]
# 842                                      []
# 141                                      []
# 690                  [bad_quality_or_taste]
# 193                                      []
# 831                                      []
# 325                  [bad_quality_or_taste]
# 347                         [good_services]
# 380                                      []
# 296                         [good_services]
# 590                  [bad_quality_or_taste]
# 516                                      []
# 662             [global_positive_feedbacks]
# 748                         [good_services]
# 826                  [bad_quality_or_taste]
# 609                                      []
# 549                                      []
# 178                  [bad_quality_or_taste]
# 132                  [bad_quality_or_taste]
# 462                                      []
# 319                                      []
# 11                                       []
# 119                         [good_services]
# 201                  [bad_quality_or_taste]
# 19                                       []
# 297                                      []
# 641                  [bad_quality_or_taste]
# 833                         [good_services]
# 664                 [good_quality_or_taste]
# 860                                      []
# 536                         [good_services]
# 191                  [bad_quality_or_taste]
# 501             [global_positive_feedbacks]
# 457                  [bad_quality_or_taste]
# 482             [global_positive_feedbacks]
# 680                                      []
# 836                                      []
# 292                                      []
# 215  [good_quality_or_taste, good_services]
# 32                          [good_services]
# 740                                      []
# 771             [global_positive_feedbacks]
# 534                         [good_services]
# 182                  [bad_quality_or_taste]
# 133                [wrong_or_missing_order]
# 47                  [good_quality_or_taste]
# 498                 [good_quality_or_taste]
# 473                                      []

# %%
val_df['predicted'].value_counts()
# Out:
# []                                               377
# [good_quality_or_taste]                          166
# [bad_quality_or_taste]                           113
# [good_services]                                  101
# [global_positive_feedbacks]                       78
# [wrong_or_missing_order]                          37
# [good_quality_or_taste, good_services]            23
# [bad_quality_or_taste, good_quality_or_taste]      3
# Name: predicted, dtype: int64
